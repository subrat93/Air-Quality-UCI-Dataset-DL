# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from datetime import datetime, date
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Read the data

# %%
df = pd.read_csv('AirQualityUCI.csv', sep=';', decimal=',', parse_dates=[['Date', 'Time']])
df.shape
# Out:
# (9471, 16)

# %%
df.head(12)
# Out:
#               Date_Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0   10/03/2004 18.00.00     2.6       1360.0     150.0      11.9
# 1   10/03/2004 19.00.00     2.0       1292.0     112.0       9.4
# 2   10/03/2004 20.00.00     2.2       1402.0      88.0       9.0
# 3   10/03/2004 21.00.00     2.2       1376.0      80.0       9.2
# 4   10/03/2004 22.00.00     1.6       1272.0      51.0       6.5
# 5   10/03/2004 23.00.00     1.2       1197.0      38.0       4.7
# 6   11/03/2004 00.00.00     1.2       1185.0      31.0       3.6
# 7   11/03/2004 01.00.00     1.0       1136.0      31.0       3.3
# 8   11/03/2004 02.00.00     0.9       1094.0      24.0       2.3
# 9   11/03/2004 03.00.00     0.6       1010.0      19.0       1.7
# 10  11/03/2004 04.00.00  -200.0       1011.0      14.0       1.3
# 11  11/03/2004 05.00.00     0.7       1066.0       8.0       1.1
#
#     PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0          1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1           955.0    103.0        1174.0     92.0        1559.0        972.0
# 2           939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3           948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4           836.0    131.0        1205.0    116.0        1490.0       1110.0
# 5           750.0     89.0        1337.0     96.0        1393.0        949.0
# 6           690.0     62.0        1462.0     77.0        1333.0        733.0
# 7           672.0     62.0        1453.0     76.0        1333.0        730.0
# 8           609.0     45.0        1579.0     60.0        1276.0        620.0
# 9           561.0   -200.0        1705.0   -200.0        1235.0        501.0
# 10          527.0     21.0        1818.0     34.0        1197.0        445.0
# 11          512.0     16.0        1918.0     28.0        1182.0        422.0
#
#        T    RH      AH  Unnamed: 15  Unnamed: 16
# 0   13.6  48.9  0.7578          NaN          NaN
# 1   13.3  47.7  0.7255          NaN          NaN
# 2   11.9  54.0  0.7502          NaN          NaN
# 3   11.0  60.0  0.7867          NaN          NaN
# 4   11.2  59.6  0.7888          NaN          NaN
# 5   11.2  59.2  0.7848          NaN          NaN
# 6   11.3  56.8  0.7603          NaN          NaN
# 7   10.7  60.0  0.7702          NaN          NaN
# 8   10.7  59.7  0.7648          NaN          NaN
# 9   10.3  60.2  0.7517          NaN          NaN
# 10  10.1  60.5  0.7465          NaN          NaN
# 11  11.0  56.2  0.7366          NaN          NaN

# %% [markdown]
# # Preprocess the data

# %%
# Extract only the required columns
df_act = df[['Date_Time', 'CO(GT)']].copy(deep=True)
df_act.tail(3)
# Out:
#      Date_Time  CO(GT)
# 9468   nan nan     NaN
# 9469   nan nan     NaN
# 9470   nan nan     NaN

# %%
#check for missing values
Temp = pd.DataFrame(df_act.isnull().sum())
Temp.columns = ['Sum']
print('Amount of rows with missing values: ' + str(len(Temp.index[Temp['Sum'] > 0])) )
# Out:
# Amount of rows with missing values: 1

# %%
df_temp = df_act[df_act['CO(GT)'] > 0]
df_temp.mean()['CO(GT)']
# Out:
# 2.1527495439145157

# %%
df_act = df_act.fillna(df_temp.mean())

# %%
df_act.head(12)
# Out:
#               Date_Time  CO(GT)
# 0   10/03/2004 18.00.00     2.6
# 1   10/03/2004 19.00.00     2.0
# 2   10/03/2004 20.00.00     2.2
# 3   10/03/2004 21.00.00     2.2
# 4   10/03/2004 22.00.00     1.6
# 5   10/03/2004 23.00.00     1.2
# 6   11/03/2004 00.00.00     1.2
# 7   11/03/2004 01.00.00     1.0
# 8   11/03/2004 02.00.00     0.9
# 9   11/03/2004 03.00.00     0.6
# 10  11/03/2004 04.00.00  -200.0
# 11  11/03/2004 05.00.00     0.7

# %%
df_act.loc[df_act['CO(GT)'] < 0, 'CO(GT)'] = df_temp.mean()['CO(GT)']
df_temp2 = df_act[df_act['CO(GT)'] <= 0]
df_temp2.shape
# Out:
# (0, 2)

# %%
df_act.head(12)
# Out:
#               Date_Time   CO(GT)
# 0   10/03/2004 18.00.00  2.60000
# 1   10/03/2004 19.00.00  2.00000
# 2   10/03/2004 20.00.00  2.20000
# 3   10/03/2004 21.00.00  2.20000
# 4   10/03/2004 22.00.00  1.60000
# 5   10/03/2004 23.00.00  1.20000
# 6   11/03/2004 00.00.00  1.20000
# 7   11/03/2004 01.00.00  1.00000
# 8   11/03/2004 02.00.00  0.90000
# 9   11/03/2004 03.00.00  0.60000
# 10  11/03/2004 04.00.00  2.15275
# 11  11/03/2004 05.00.00  0.70000

# %%
df_act.drop(df_act[df_act['Date_Time'] == 'nan nan'].index, inplace = True) 
df_act.shape
# Out:
# (9357, 2)

# %%
from datetime import datetime
df_act['Date_Time'] = pd.to_datetime(df_act['Date_Time'], format = '%d/%m/%Y %H.%M.%S')

# %%
df_act.head()
# Out:
#             Date_Time  CO(GT)
# 0 2004-03-10 18:00:00     2.6
# 1 2004-03-10 19:00:00     2.0
# 2 2004-03-10 20:00:00     2.2
# 3 2004-03-10 21:00:00     2.2
# 4 2004-03-10 22:00:00     1.6

# %%
df_act = df_act.set_index('Date_Time')
df_act.head(3)
# Out:
#                      CO(GT)
# Date_Time
# 2004-03-10 18:00:00     2.6
# 2004-03-10 19:00:00     2.0
# 2004-03-10 20:00:00     2.2

# %% [markdown]
# # Visualize the Actual Data

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(15,7))
plt.plot(df_act.iloc[0:200]['CO(GT)'])
plt.show()

# %% [markdown]
# # Stationarity Test - Dickey Fuller

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
#     rolmean = pd.rolling_mean(timeseries, window=12)
    rolmean = timeseries.rolling(12).mean()
#     rolstd = pd.rolling_std(timeseries, window=12)
    rolstd = timeseries.rolling(12).std()

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    data1 = timeseries.iloc[:,0].values
    dftest = adfuller(data1, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationarity(df_act)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.105066e+01
# p-value                        5.089830e-20
# #Lags Used                     3.600000e+01
# Number of Observations Used    9.320000e+03
# Critical Value (1%)           -3.431052e+00
# Critical Value (5%)           -2.861850e+00
# Critical Value (10%)          -2.566935e+00
# dtype: float64

# %% [markdown]
# # Determine p, d and q for ARIMA

# %%
#ACF and PACF plots:
from statsmodels.tsa.stattools import acf, pacf

# %%
lag_acf = acf(df_act, nlags=20)
lag_pacf = pacf(df_act, nlags=20, method='ols')

# %%
#Plot ACF: 
import numpy as np
plt.figure(figsize=(20,7))
plt.subplot(121) 
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(df_act)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(df_act)),linestyle='--',color='gray')
plt.title('Autocorrelation Function')
# Out:
# Text(0.5, 1.0, 'Autocorrelation Function')

# %%
#Plot PACF:
plt.figure(figsize=(20,7))
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(df_act)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(df_act)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()

# %% [markdown]
# # Create the ARIMA model and predict

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
model = ARIMA(df_act.head(9000), order=(1, 0, 1))  
results_AR = model.fit(disp=-1)  
plt.plot(df_act)
plt.plot(results_AR.fittedvalues, color='red')
# plt.plot(df_act[9001:], color='green')
plt.title('RSS: %.4f'% sum((results_AR.fittedvalues-df_act)**2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-17373d77783e> in <module>
#       4 plt.plot(results_AR.fittedvalues, color='red')
#       5 # plt.plot(df_act[9001:], color='green')
# ----> 6 plt.title('RSS: %.4f'% sum((results_AR.fittedvalues-df_act)**2))
#
# pandas\_libs\tslibs\timestamps.pyx in pandas._libs.tslibs.timestamps.Timestamp.__radd__()
#
# pandas\_libs\tslibs\timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# ValueError: Cannot add integral value to Timestamp without freq.

# %%
results_AR.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                 CO(GT)   No. Observations:                 9000
# Model:                     ARMA(1, 1)   Log Likelihood              -10123.512
# Method:                       css-mle   S.D. of innovations              0.745
# Date:                Fri, 27 Sep 2019   AIC                          20255.025
# Time:                        11:25:20   BIC                          20283.444
# Sample:                    03-10-2004   HQIC                         20264.695
#                          - 03-20-2005
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            2.1623      0.037     58.805      0.000       2.090       2.234
# ar.L1.CO(GT)     0.7300      0.009     85.362      0.000       0.713       0.747
# ma.L1.CO(GT)     0.2642      0.012     22.420      0.000       0.241       0.287
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.3698           +0.0000j            1.3698            0.0000
# MA.1           -3.7848           +0.0000j            3.7848            0.5000
# -----------------------------------------------------------------------------
# """

# %%
# Plot residual errors
residuals = pd.DataFrame(results_AR.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %%
# Actual vs Fitted
plt.figure(figsize=(25,17))
results_AR.plot_predict(dynamic=False)
plt.show()

# %%
from statsmodels.tsa.stattools import acf

# Create Training and Test
train = df_act[:9000]
test = df_act[9000:]

# %%
# Forecast
fc, se, conf = results_AR.forecast(357, alpha=0.05)  # 95% conf
fc
# Out:
# array([1.61515399, 1.76286219, 1.87069538, 1.94941813, 2.00688904,
#        2.04884522, 2.07947499, 2.10183601, 2.11816049, 2.13007804,
#        2.13877836, 2.14512995, 2.14976689, 2.15315204, 2.15562335,
#        2.1574275 , 2.15874461, 2.15970616, 2.16040813, 2.16092059,
#        2.16129471, 2.16156784, 2.16176723, 2.1619128 , 2.16201906,
#        2.16209664, 2.16215328, 2.16219463, 2.16222481, 2.16224685,
#        2.16226294, 2.16227468, 2.16228326, 2.16228952, 2.16229409,
#        2.16229742, 2.16229986, 2.16230164, 2.16230293, 2.16230388,
#        2.16230457, 2.16230508, 2.16230545, 2.16230572, 2.16230591,
#        2.16230606, 2.16230616, 2.16230624, 2.16230629, 2.16230633,
#        2.16230636, 2.16230639, 2.1623064 , 2.16230641, 2.16230642,
#        2.16230643, 2.16230643, 2.16230643, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644, 2.16230644, 2.16230644, 2.16230644,
#        2.16230644, 2.16230644])

# %%
# Make as pandas series
fc_series = pd.Series(fc, index=test.index)
lower_series = pd.Series(conf[:, 0], index=test.index)
upper_series = pd.Series(conf[:, 1], index=test.index)

# %%
# Plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train[8500:], label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()
